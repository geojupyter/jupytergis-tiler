# %% [markdown]
# # Computing tiles on the fly from an Xarray dataset

# %% [markdown]
# In this notebook, we'll show how to visualize local data. To execute it, you will need to install these packages:

# %%
# !pip install rioxarray xarray rich ipywidgets dask matplotlib
# Out:
# Requirement already satisfied: rioxarray in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (0.19.0)
# Requirement already satisfied: xarray in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (2025.4.0)
# Requirement already satisfied: rich in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (14.0.0)
# Requirement already satisfied: ipywidgets in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (8.1.7)
# Requirement already satisfied: dask in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (2025.4.1)
# Requirement already satisfied: matplotlib in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (3.10.3)
# Requirement already satisfied: packaging in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rioxarray) (25.0)
# Requirement already satisfied: rasterio>=1.4.3 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rioxarray) (1.4.3)
# Requirement already satisfied: pyproj>=3.3 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rioxarray) (3.7.1)
# Requirement already satisfied: numpy>=1.23 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rioxarray) (2.2.5)
# Requirement already satisfied: pandas>=2.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rich) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rich) (2.19.1)
# Requirement already satisfied: comm>=0.1.3 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipywidgets) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: click>=8.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from dask) (8.2.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from dask) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from dask) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from dask) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: decorator in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: stack_data in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from pandas>=2.1->xarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from pandas>=2.1->xarray) (2025.2)
# Requirement already satisfied: locket in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from partd>=1.4.0->dask) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: certifi in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from pyproj>=3.3->rioxarray) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: affine in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rasterio>=1.4.3->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rasterio>=1.4.3->rioxarray) (25.3.0)
# Requirement already satisfied: cligj>=0.5 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rasterio>=1.4.3->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from rasterio>=1.4.3->rioxarray) (1.1.1)
# Requirement already satisfied: executing>=1.2.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/david/.local/share/mamba/envs/jupytergis-tiler/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from pathlib import Path
from zipfile import ZipFile

import httpx
import rioxarray
import xarray as xr
from rich.progress import track

from jupytergis.tiler import GISDocument

# %% [markdown]
# We will display the DEM (digital elevation model) for Asia from the [HydroSHEDS](https://www.hydrosheds.org/) dataset, which represents the terrain. Let's first download the data:

# %%
url = "https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/hydrosheds/sa_30s_zip_grid/as_dem_30s_grid.zip"
filename = Path(url).name
name = filename[: filename.find("_grid")]
adffile = Path(name) / name / "w001001.adf"

if not adffile.exists():
    with httpx.stream("GET", url) as r, open(filename, "wb") as f:
        total = int(r.headers["Content-Length"]) / 1024
        for data in track(
            r.iter_bytes(chunk_size=1024), total=total, description="Downloading"
        ):
            f.write(data)
        f.flush()
    zip = ZipFile(filename)
    zip.extractall(".")

# %% [markdown]
# It is a dataset that [Rasterio](https://rasterio.readthedocs.io) can open, but in order to get a nice `DataArray` with all the metadata taken into account, we'll open it with [rioxarray](https://corteva.github.io/rioxarray):

# %%
da = rioxarray.open_rasterio(adffile, masked=True)
da
# Out:
# <xarray.DataArray (band: 1, y: 8400, x: 15000)> Size: 504MB
# [126000000 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 120kB 55.0 55.01 55.02 55.03 ... 180.0 180.0 180.0
#   * y            (y) float64 67kB 60.0 59.99 59.98 ... -9.979 -9.988 -9.996
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0

# %% [markdown]
# The projection is `EPSG:4326` (aka `WGS84`). Here the coordinate `x` corresponds to longitudes, and `y` to latitudes (in degrees). There is only one band.

# %%
da = da.sel(band=1)

# %% [markdown]
# The dataset can be too big to hold in memory, so we will chunk it into smaller pieces. That will also improve performances as the generation of a tile can be done in parallel using Dask.

# %%
da = da.chunk(dict(x=1000, y=1000))

# %% [markdown]
# Now let's save this data array in a dataset, as a Zarr store:

# %% [markdown]
# We'll need the minimum and maximum values of the DEM to rescale our tiles:

# %%
vmin, vmax = int(da.min().compute()), int(da.max().compute())
vmin, vmax
# Out:
# (-158, 8247)

# %% [markdown]
# We are now ready to show a *tiler layer*, which computes the tiles on the fly:

# %%
Path("xarray.jGIS").unlink(missing_ok=True)
doc = GISDocument("xarray.jGIS")
doc

# %%
await doc.add_tiler_layer(
    name="Xarray Layer",
    data_array=da,
    colormap_name="viridis",
    rescale=(vmin, vmax),
)

# %%
# not mandatory, but helps shutting down the kernel gracefully:
# await doc.stop_tile_server()
